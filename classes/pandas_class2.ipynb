# %% [markdown]
# ## Class 2 - Pandas

# %%
# Importing libraries
import pandas as pd

# %% [markdown]
# ### Reading data

# %%
# Path to csv file
data_path = 'https://raw.githubusercontent.com/agconti/kaggle-titanic/master/data/test.csv'

# %%
# Reading csv with read_csv method
raw_data = pd.read_csv(data_path)
df = raw_data.copy()

# %%
# Showing data header
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### Renaming columns

# %%
def rename_columns(data: pd.DataFrame, columns: dict):
    return data.rename(columns, axis=1)

# %%
columns_to_rename = {
    'PassengerId': 'passagender_id',
    'Pclass': 'class'
}

# %%
# Trying to rename column
rename_columns(df, columns_to_rename)
# Out:
#      passagender_id  class                                          Name  \
# 0               892      3                              Kelly, Mr. James
# 1               893      3              Wilkes, Mrs. James (Ellen Needs)
# 2               894      2                     Myles, Mr. Thomas Francis
# 3               895      3                              Wirz, Mr. Albert
# 4               896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..              ...    ...                                           ...
# 413            1305      3                            Spector, Mr. Woolf
# 414            1306      1                  Oliva y Ocana, Dona. Fermina
# 415            1307      3                  Saether, Mr. Simon Sivertsen
# 416            1308      3                           Ware, Mr. Frederick
# 417            1309      3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
# Checking if columns were renamed
df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### Note
#
# As we can see above, the columns was not renamed. There're two ways to fix this:

# %%
# 1 - Return value of function
renamed_df_with_fn = rename_columns(df, columns_to_rename)
renamed_df_with_fn.head()
# Out:
#    passagender_id  class                                          Name  \
# 0             892      3                              Kelly, Mr. James
# 1             893      3              Wilkes, Mrs. James (Ellen Needs)
# 2             894      2                     Myles, Mr. Thomas Francis
# 3             895      3                              Wirz, Mr. Albert
# 4             896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0    male  34.5      0      0   330911   7.8292   NaN        Q
# 1  female  47.0      1      0   363272   7.0000   NaN        S
# 2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3    male  27.0      0      0   315154   8.6625   NaN        S
# 4  female  22.0      1      1  3101298  12.2875   NaN        S

# %%
# 2 - Inplace parameter

# Rewrite the function
def rename_columns(data: pd.DataFrame, columns: dict):
    data.rename(columns, axis=1, inplace=True)
    
rename_columns(df, columns_to_rename)
df.head()
# Out:
#    passagender_id  class                                          Name  \
# 0             892      3                              Kelly, Mr. James
# 1             893      3              Wilkes, Mrs. James (Ellen Needs)
# 2             894      2                     Myles, Mr. Thomas Francis
# 3             895      3                              Wirz, Mr. Albert
# 4             896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0    male  34.5      0      0   330911   7.8292   NaN        Q
# 1  female  47.0      1      0   363272   7.0000   NaN        S
# 2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3    male  27.0      0      0   315154   8.6625   NaN        S
# 4  female  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### Normalizing column names
#
# Setting columns to lower case

# %%
def normalize_columns(data: pd.DataFrame):
    data.columns = [col.lower() for col in data.columns]

# %%
normalize_columns(df)
df.head()
# Out:
#    passagender_id  class                                          name  \
# 0             892      3                              Kelly, Mr. James
# 1             893      3              Wilkes, Mrs. James (Ellen Needs)
# 2             894      2                     Myles, Mr. Thomas Francis
# 3             895      3                              Wirz, Mr. Albert
# 4             896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       sex   age  sibsp  parch   ticket     fare cabin embarked
# 0    male  34.5      0      0   330911   7.8292   NaN        Q
# 1  female  47.0      1      0   363272   7.0000   NaN        S
# 2    male  62.0      0      0   240276   9.6875   NaN        Q
# 3    male  27.0      0      0   315154   8.6625   NaN        S
# 4  female  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ### Checking data quality

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   passagender_id  418 non-null    int64
#  1   class           418 non-null    int64
#  2   name            418 non-null    object
#  3   sex             418 non-null    object
#  4   age             332 non-null    float64
#  5   sibsp           418 non-null    int64
#  6   parch           418 non-null    int64
#  7   ticket          418 non-null    object
#  8   fare            417 non-null    float64
#  9   cabin           91 non-null     object
#  10  embarked        418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
# Checking null values
fill_percent = df.count() / df.shape[0] * 100

# %%
fill_percent
# Out:
# passagender_id    100.000000
# class             100.000000
# name              100.000000
# sex               100.000000
# age                79.425837
# sibsp             100.000000
# parch             100.000000
# ticket            100.000000
# fare               99.760766
# cabin              21.770335
# embarked          100.000000
# dtype: float64

# %%
def calculate_fill_pecentage(data: pd.DataFrame):
    fill_percentage = df.count() / df.shape[0] * 100
    
    return pd.DataFrame(
        {'column': fill_percentage.index, 
         'percentage': fill_percentage.values
        }
    )

# %%
df_fill_perc = calculate_fill_pecentage(df)
df_fill_perc
# Out:
#             column  percentage
# 0   passagender_id  100.000000
# 1            class  100.000000
# 2             name  100.000000
# 3              sex  100.000000
# 4              age   79.425837
# 5            sibsp  100.000000
# 6            parch  100.000000
# 7           ticket  100.000000
# 8             fare   99.760766
# 9            cabin   21.770335
# 10        embarked  100.000000

# %%
df_fill_perc['percentage'] < 100
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6     False
# 7     False
# 8      True
# 9      True
# 10    False
# Name: percentage, dtype: bool

# %%
# Finding columns where fill percentage is lower than 100
df_fill_perc[df_fill_perc['percentage'] < 100]
# Out:
#   column  percentage
# 4    age   79.425837
# 8   fare   99.760766
# 9  cabin   21.770335

# %% [markdown]
# ### Fixing missing values

# %%
columns_with_null = df_fill_perc[df_fill_perc['percentage'] < 100]['column'].values
columns_with_null
# Out:
# array(['age', 'fare', 'cabin'], dtype=object)

# %%
for column in columns_with_null:
    qty = df[df[column].isnull()].shape[0]
    
    print(f"There are {qty} missing values at {column} column")
# Out:
# There are 86 missing values at age column
# There are 1 missing values at fare column
# There are 327 missing values at cabin column

# %%
# Checking dtypes
df[columns_with_null].dtypes
# Out:
# age      float64
# fare     float64
# cabin     object
# dtype: object

# %%
df[columns_with_null].head()
# Out:
#     age     fare cabin
# 0  34.5   7.8292   NaN
# 1  47.0   7.0000   NaN
# 2  62.0   9.6875   NaN
# 3  27.0   8.6625   NaN
# 4  22.0  12.2875   NaN

# %% [markdown]
# ###  Fixing age column

# %%
avg_age = round(df['age'].mean(), 2)
avg_age
# Out:
# 30.27

# %%
# Wrong way
df['age'].fillna(avg_age)
# Out:
# 0      34.50
# 1      47.00
# 2      62.00
# 3      27.00
# 4      22.00
#        ...
# 413    30.27
# 414    39.00
# 415    38.50
# 416    30.27
# 417    30.27
# Name: age, Length: 418, dtype: float64

# %%
# Not the best approach
df['age'] = df['age'].fillna(avg_age)

# %%
# Better way
df['age'].fillna(avg_age, inplace=True)

# %% [markdown]
# ### Fixing fare column

# %%
median_fare = df['fare'].median()

# %%
df['fare'].fillna(median_fare, inplace=True)

# %% [markdown]
# ### Fixing cabin

# %%
df['cabin']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#        ...
# 413     NaN
# 414    C105
# 415     NaN
# 416     NaN
# 417     NaN
# Name: cabin, Length: 418, dtype: object

# %%
df['cabin'].fillna('unknown', inplace=True)

# %%
df.head()
# Out:
#    passagender_id  class                                          name  \
# 0             892      3                              Kelly, Mr. James
# 1             893      3              Wilkes, Mrs. James (Ellen Needs)
# 2             894      2                     Myles, Mr. Thomas Francis
# 3             895      3                              Wirz, Mr. Albert
# 4             896      3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
#
#       sex   age  sibsp  parch   ticket     fare    cabin embarked
# 0    male  34.5      0      0   330911   7.8292  unknown        Q
# 1  female  47.0      1      0   363272   7.0000  unknown        S
# 2    male  62.0      0      0   240276   9.6875  unknown        Q
# 3    male  27.0      0      0   315154   8.6625  unknown        S
# 4  female  22.0      1      1  3101298  12.2875  unknown        S

# %%
calculate_fill_pecentage(df)
# Out:
#             column  percentage
# 0   passagender_id       100.0
# 1            class       100.0
# 2             name       100.0
# 3              sex       100.0
# 4              age       100.0
# 5            sibsp       100.0
# 6            parch       100.0
# 7           ticket       100.0
# 8             fare       100.0
# 9            cabin       100.0
# 10        embarked       100.0

# %%
df.to_gbq(
    destination_table='sandbox.titanic',
    project_id='white-script-238515'
)
# Out:
# 1it [00:03,  3.73s/it]
